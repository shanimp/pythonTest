# %%
import numpy as np
import pandas as pd
import matplotlib as plt

twitter = pd.read_csv("Twitter.csv")

pd = twitter.head()
print(pd)
pd = twitter.info()
print(pd)
# Out:
#    1
# 0  2
# 1  3
# 2  4
# 3  5
# 4  6
# <class 'pandas.DataFrame'>
# RangeIndex: 11316810 entries, 0 to 11316809
# Data columns (total 1 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   1       int64
# dtypes: int64(1)
# memory usage: 86.3 MB
# None

# %%
import numpy as np
import pandas as pd
import matplotlib as plt

yt = pd.read_csv("youtube.csv")

pd = yt.head()
print(pd)
pd = yt.info()
print(pd)
# Out:
#   72\t165\t517\t875\t1024\t1742\t2059\t2252\t2429\t3622\t5036\t5080\t5088\t5703\t5873\t6723\t6752\t8459\t8752\t8885\t9553\t10243\t10763\t13040\t13841\t15059\t15231\t15310\t16100\t19170\t19573\t20572\t26797\t27414\t28080\t28084\t28755\t40404\t43824\t48404\t48423\t48431\t61005\t83295\t103527\t108236\t139888\t156355\t156534\t175210\t180201\t181647\t181664\t181665\t183004\t203349\t224411\t279007\t282577\t287218\t319813\t458127\t526519\t645203
# 0  1\t3\t5\t539\t551\t554\t571\t626\t642\t673\t67...
# 1                                     519665\t608725
# 2                                     282492\t406981
# 3                                     234132\t234134
# 4                                     157240\t459129
# <class 'pandas.DataFrame'>
# RangeIndex: 16385 entries, 0 to 16384
# Data columns (total 1 columns):
# ...

# %%
twitter_numeric = twitter.select_dtypes(include=['int64','float64'])

print("Twitter Numerical Attributes:")
print(twitter_numeric.columns)
# Out:
# Twitter Numerical Attributes:
# Index(['1'], dtype='str')

# %%
youtube_numeric = twitter.select_dtypes(include=['int64','float64'])

print("youTube Numerical Attributes:")
print(youtube_numeric.columns)
# Out:
# youTube Numerical Attributes:
# Index(['1'], dtype='str')

# %%
twt_mean = sum(twitter_numeric)/
